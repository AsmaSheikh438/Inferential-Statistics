# %% [markdown]
# ![chi square test - Yahoo India Image Search results - Google Chrome 21-11-2024 20_47_56.png](attachment:0deb6e2c-a0ab-4ee2-992d-34162e72cdd0.png)

# %% [markdown]
# ![chi square test - Yahoo India Image Search results - Google Chrome 21-11-2024 20_46_19.png](attachment:e43404e1-a451-4c10-8907-273c1e5fa70f.png)

# %% [markdown]
# ![chi square test - Yahoo India Image Search results - Google Chrome 21-11-2024 20_49_22.png](attachment:d14df434-300d-4704-95bc-df81c3ed2b48.png)

# %% [markdown]
# ![WhatsApp Image 2024-11-21 at 20.57.08_bd99d81f.jpg](attachment:86a7aa0f-8f04-474b-9c67-e535f13d2d7f.jpg)

# %% [markdown]
# ## Ho = die is fair
# ## Ha = die is not fair

# %% [markdown]
# #### by chi square table we get chi square value = 11.07
# #### df = n-1 , 6-1 = 5 , df=5

# %%
# calculating chi calculated value putting all value in formula we get
import numpy as np

# %%
ob = np.array([22,17,20,26,22,13]) # observation value
ex = np.array([20,20,20,20,20,20,]) # excepted value

# %%
ob-ex
# Out:
# array([ 2, -3,  0,  6,  2, -7])

# %%
np.sum(np.square(ob-ex)/ex)
# Out:
# 5.1000000000000005

# %%
# so chi calculated value we get
Chi= 5.1

# %% [markdown]
# ![WhatsApp Image 2024-11-23 at 13.18.16_3891c104.jpg](attachment:903820e5-2974-4b62-aff9-81941662715a.jpg)

# %% [markdown]
# #### Conclusion = Ho is fair (die work in fair condition)
