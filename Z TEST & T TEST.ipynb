# %% [markdown]
# ## Z TEST

# %%
import scipy.stats as st
import numpy as np

# %%
s_x = 90 # sample
p_u = 82 # population
p_std = 20
n = 81
ap = 0.05

# %%
Z_cal = (s_x - p_u)/(p_std/np.sqrt(n))
Z_cal
# Out:
# 3.5999999999999996

# %%
Z_table = st.norm.ppf(1-ap)
Z_table
# Out:
# 1.6448536269514722

# %%
if Z_table< Z_cal:
    print("Ha is right")
else: 
    print("Ho is right")
# Out:
# Ha is right

# %% [markdown]
# ## T TEST
# A t-test is a type of inferential statistic test used to determine if there is a significant difference between the means of two groups. It is often used when data is normally distributed and population variance is unknown.
#
# The t-test is used in hypothesis testing to assess whether the observed difference between the means of the two groups is statistically significant or just due to random variation.
#
# * In addition, a t test uses a t-statistic and compares this to t-distribution values to determine if the results are statistically significant.
#
# * However, note that you can only uses a t test to compare two means. If you want to compare three or more means, use an ANOVA instead.

# %% [markdown]
# #### The T Score
# The t score is a ratio between the difference between two groups and the difference within the groups.
#
# * Larger t scores = more difference between groups.
# * Smaller t score = more similarity between groups

# %% [markdown]
# #### Conditions for T TEST
# * Must have population data mean
# * Must have sample data mean
# * Must have sample data (std) standard deviation
# * Have No. of sample data less tha < 30

# %% [markdown]
# ![t-test formula - Derivation, Examples - Google Chrome 21-11-2024 19_39_20.png](attachment:b5e7d2c4-de31-40f4-abcd-492e15825602.png)

# %% [markdown]
# ![t-test formula - Derivation, Examples - Google Chrome 21-11-2024 19_39_36.png](attachment:2acd5e0e-320e-4179-a607-aaa7e81b44e4.png)

# %% [markdown]
# *   x = sample mean
# *    u = population mean
# * a = satndard deviation
# *     n = no. of sample

# %% [markdown]
# ### Real world example

# %% [markdown]
# ![WhatsApp Image 2024-11-21 at 19.51.00_337a9d6c.jpg](attachment:4d4b1fa8-1096-4b3a-8086-870d9f597cb0.jpg)

# %% [markdown]
# ![WhatsApp Image 2024-11-21 at 20.06.04_80374edc.jpg](attachment:679d7f94-13a7-487a-b8fa-bc36072359c1.jpg)

# %% [markdown]
# ![WhatsApp Image 2024-11-21 at 20.14.12_679b47fa.jpg](attachment:790a763d-99c2-4038-b93d-eaf979c6f682.jpg)

# %% [markdown]
# ![WhatsApp Image 2024-11-21 at 20.19.10_3c27c339.jpg](attachment:533e6b1c-c758-4151-a54e-0a8646a75b96.jpg)

# %%
# find out the t value
import scipy.stats as st

# %%
t_table = st.t.ppf(0.05,24) # value is neg- this is left tail test
t_table
# Out:
# -1.7108820799094282

# %% [markdown]
# # putting all value in a formula we get
# * x = 148
# * u = 150
# * s = 5
# * n = 25

# %% [markdown]
# #### t_cal = -2

# %% [markdown]
# #### conclusion = The weightage is less than 150 gm so, the complaining claimed is wrong.
